# %%
import matplotlib.pyplot as plt
sounak_SEM={"sem1":7.26 ,"sem2":7.61,"sem3":7.86,"sem4":7.27}

# creating the bar plot
plt.bar(dic.keys(), dic.values(), color='red', width=0.3, label='Sounak' )
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# create a DataFrame from the given dictionary
sounak_SEM={"sem1":7.26 ,"sem2":7.61,"sem3":7.86,"sem4":7.27}
vars= pd.DataFrame(sounak_SEM.items(), columns=['semester', 'grade'])
print(vars)

# create a line chart

vars.plot(x='semester', y='grade', kind='line', title='Sounak',)
plt.show()
# Out:
#   semester  grade
# 0     sem1   7.26
# 1     sem2   7.61
# 2     sem3   7.86
# 3     sem4   7.27
