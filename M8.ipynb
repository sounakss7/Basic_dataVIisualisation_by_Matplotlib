# %%
#step plot
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,1,3,5,4]
plt.step(x,y,label='step plot',marker='o',color='blue')
plt.grid()
plt.legend()
plt.title('Step Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')
