# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[3,4,5,6,7]
plt.plot(x,y)
plt.xlim(0,10)
plt.xticks([1,2,3,4,5],labels=["python","c","c++","java","r"])
plt.ylim(0,10)

plt.yticks([3,4,5,6,7])
# Out:
# ([<matplotlib.axis.YTick at 0x22c87dea6d0>,
# ...
#  [Text(0, 3, '3'),
#   Text(0, 4, '4'),
#   Text(0, 5, '5'),
#   Text(0, 6, '6'),
#   Text(0, 7, '7')])
