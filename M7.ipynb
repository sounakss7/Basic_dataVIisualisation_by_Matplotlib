# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [5,6,7,3,2]
z=  [1, 2, 3, 4, 5]
l= ["area1","area2","area3"]
c=["red","blue","yellow"]
plt.stackplot(x, y,z,x,labels=l,colors=c,baseline="sym")
plt.legend()
