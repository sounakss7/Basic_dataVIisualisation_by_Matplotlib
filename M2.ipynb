# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#sample scatter plot data
x=[1,2,3,4,5,6,7,8]
y=[7.26,7.61,7.86,7.27,9,6,5,3]
size=[100,160,270,380,100,160,270,380]
plt.scatter(x,y,color='red',s=size,alpha=0.9,marker="*",edgecolors="black",cmap="viridis")
plt.colorbar()

plt.xlabel('Semester')
plt.title('Sounak')
# Out:
# C:\Users\souna\AppData\Local\Temp\ipykernel_24768\43273125.py:7: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y,color='red',s=size,alpha=0.9,marker="*",edgecolors="black",cmap="viridis")
# Text(0.5, 1.0, 'Sounak')
