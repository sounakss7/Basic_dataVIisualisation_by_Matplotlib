# %%
import matplotlib.pyplot as plt
x=["sem1","sem2","sem3","sem4"]
y=[7.26,7.61,7.86,7.27]
z=["y","b","r","g"]

plt.bar(x,y,width=0.4,color=z,edgecolor="black",linewidth=2, label="grade")
plt.bar(y,z,width=0.3,color="orange",edgecolor="black",linewidth=2, label="grade2")
plt.legend()
plt.xticks(x,y)
plt.title("sounak grade")
plt.show()
